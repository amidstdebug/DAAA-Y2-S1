# %% [markdown]
# # Practical 2: Systems of Linear Equations
#
# In this practical, we will write code the Gaussian elimination algorithm to solve a system of linear equations with unique solution.

# %% [markdown]
# ### Task 1
#
# Solve the following system of linear equations
#
# \begin{equation}
# 2x_1 + 4x_2 + 6x_3 = 22 \\
# 3x_1 + 8x_2 + 5x_3 = 27 \\
# -x_1 + x_2 + 2x_3 = 2 \\
# \end{equation}
#
#
#
# given that it has unique solution.

# %%
import numpy as np

a = np.array([[2,-3,0], [2, 1, 0], [3, 2, 0]])

np.linalg.det(a)
# Out:
# 0.0

# %%
A = np.array([[2, 4, 6], [3, 8, 5], [-1, 1, 2]], dtype='float')
b = np.array([22, 27, 2])
Ab = np.hstack([A, b.reshape(-1, 1)])
# A[2] *= 3
A[2] *= 3
A[2] = A[1] + A[2]
A
# Out:
# array([[ 2.,  4.,  6.],
#        [ 3.,  8.,  5.],
#        [ 0., 11., 11.]])

# %%
b = np.array([22, 27, 2])
b
# Out:
# array([22, 27,  2])

# %%
Ab = np.hstack([A, b.reshape(-1, 1)])
Ab
# Out:
# array([[ 2.,  4.,  6., 22.],
#        [ 3.,  8.,  5., 27.],
#        [ 0., 11., 11.,  2.]])

# %% [markdown]
# Find the number of linear equations and store in n.

# %%
n = len(b)

# %% [markdown]
# The algorithm below is used to convert the augmented matrix to row echelon form.<br>
# Illustrated below is the algorithm applied to this example:
#
# \begin{bmatrix}
# \begin{array}{c c c|c}
#   2 & 4 & 6 & 22 \\
#   3 & 8 & 5 & 27 \\
#   -1 & 1 & 2 & 2
#  \end{array}
# \end{bmatrix}
#
#
#
#
# $\xrightarrow[R_{3}-(-\frac{1}{2}R_{1})]{R_{2}-\frac{3}{2}R_{1}}$
# \begin{bmatrix}
# \begin{array}{c c c|c}
#   2 & 4 & 6 & 22 \\
#   0 & 2 & -4 & -6 \\
#   0 & 3 & 5 & 13
#  \end{array}
# \end{bmatrix}
#
#
#
# $
# \xrightarrow[]{R_{3}-\frac{3}{2}R_{2}}
# \begin{bmatrix}
# \begin{array}{c c c|c}
#   2 & 4 & 6 & 22 \\
#   0 & 2 & -4 & -6 \\
#   0 & 0 & 11 & 22
#  \end{array}
# \end{bmatrix}
# $

# %%
n = 3

#Converts augmented matrix to row echelon form
for i in range(n):
    a = Ab[i]

    for j in range(i + 1, n):
        b = Ab[j]
        m = b[i] / a[i]
        Ab[j] = b - m * a

# %%
Ab
# Out:
# array([[ 2.,  4.,  6., 22.],
#        [ 0.,  2., -4., -6.],
#        [ 0.,  0., 33., 35.]])

# %% [markdown]
# The algorithm below is used to convert row echelon form to reduced row echelon form (only one '1' in each row on the left side of the augmented matrix).<br>
# Illustrated below is the algorithm applied to this example:
#
# \begin{bmatrix}
# \begin{array}{c c c|c}
#   2 & 4 & 6 & 22 \\
#   0 & 2 & -4 & -6 \\
#   0 & 0 & 11 & 22
#  \end{array}
# \end{bmatrix}$$
#
# $\xrightarrow[]{\frac{1}{11}R_{3}}$
# \begin{bmatrix}
# \begin{array}{c c c|c}
#   2 & 4 & 6 & 22 \\
#   0 & 2 & -4 & -6 \\
#   0 & 0 & 1 & 2
#  \end{array}
# \end{bmatrix}
#
#
#
# $\xrightarrow[-\frac{1}{6}R_{1} + R_{3}]{-(\frac{1}{-4})R_{2} + R_{3}}$
# \begin{bmatrix}
# \begin{array}{c c c|c}
#   -\frac{1}{3} & -\frac{2}{3} & 0 & -\frac{5}{3} \\
#   0 & \frac{1}{2} & 0 & \frac{1}{2} \\
#   0 & 0 & 1 & 2
#  \end{array}
# \end{bmatrix}
#
#
# $\xrightarrow[]{\frac{1}{0.5}R_{2}}$
# \begin{bmatrix}
# \begin{array}{c c c|c}
#   -\frac{1}{3} & -\frac{2}{3} & 0 & -\frac{5}{3} \\
#   0 & 1 & 0 & 1 \\
#   0 & 0 & 1 & 2
#  \end{array}
# \end{bmatrix}
#
#
# $\xrightarrow[]{-\frac{1}{-\frac{2}{3}}R_{1} + R_{2}} $
# \begin{bmatrix}
# \begin{array}{c c c|c}
#   -\frac{1}{2} & 0 & 0 & -\frac{3}{2} \\
#   0 & 1 & 0 & 1 \\
#   0 & 0 & 1 & 2
#  \end{array}
# \end{bmatrix}
#
#
# $\xrightarrow[]{\frac{1}{-0.5}R_{1}} $
# \begin{bmatrix}
# \begin{array}{c c c|c}
#   1 & 0 & 0 & 3 \\
#   0 & 1 & 0 & 1 \\
#   0 & 0 & 1 & 2
#  \end{array}
# \end{bmatrix}

# %%
#Converts row echelon form to reduced row echelon form
for i in range(n - 1, -1, -1):
    Ab[i] = Ab[i] / Ab[i, i]
    a = Ab[i]

    for j in range(i - 1, -1, -1):
        b = Ab[j]
        m = a[i] / b[i]
        Ab[j] = a - m * b
Ab
# Out:
# array([[ 1.        , -0.        , -0.        ,  9.57575758],
#        [ 0.        ,  1.        ,  0.        , -0.87878788],
#        [ 0.        ,  0.        ,  1.        ,  1.06060606]])

# %% [markdown]
# We can now have the answers<br>
#
# \begin{equation}
# x_1 = 3 \\
# x_2 = 1 \\
# x_3 = 2 \\
# \end{equation}

# %%
x = Ab[:, n]
x
# Out:
# array([ 9.57575758, -0.87878788,  1.06060606])

# %% [markdown]
# ### Task 2
#
# Modify the code from task 1 and use it to solve the following system of linear equations
#
# \begin{equation}
# 2x_2 + 3x_3 = 7 \\
# 3x_1 + 6x_2 - 12x_3 = -3 \\
# 5x_1 - 2x_2 +  2x_3 = -7 \\
# \end{equation}
#
# given that it has unique solution.<br>
# Hint: You will need to make an improvement to the section of the code that converts the augmented matrix to row echelon form.

# %%
A = np.array([[0, 2, 3], [3, 6, -12], [5, -2, 2]], dtype='float')
b = np.array([7, -3, -7])
Ab = np.hstack([A, b.reshape(-1, 1)])

n = len(b)

# %%
from IPython.core.display import display

A = np.array([[1, -1, 0], [1, 0, -1], [-6, 2, 3]])
b = np.array([[3], [-2], [0]])
Ab = np.hstack([A, b])
display(Ab)


#Converts augmented matrix to row echelon form. Modify this part.
for i in range(n):
    if Ab[i,i] == 0:
        temp = Ab[i].copy()

        for k in range (i + 1, n):
            if Ab[k, i] != 0:
                Ab[i] = Ab[k].copy()
                Ab[k] = temp.copy()
                break

    a = Ab[i]

    for j in range(i + 1, n):
        b = Ab[j]
        m = b[i] / a[i]
        Ab[j] = b - m * a

for i in range(n - 1, -1, -1):
    Ab[i] = Ab[i] / Ab[i, i]
    a = Ab[i]

    for j in range(i - 1, -1, -1):
        b = Ab[j]
        m = a[i] / b[i]
        Ab[j] = a - m * b

Ab
# Out:
# array([[ 1, -1,  0,  3],
#        [ 1,  0, -1, -2],
#        [-6,  2,  3,  0]])
# C:\Users\justi\anaconda3\envs\tensor2\lib\site-packages\ipykernel_launcher.py:33: RuntimeWarning: divide by zero encountered in long_scalars
# C:\Users\justi\anaconda3\envs\tensor2\lib\site-packages\ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in multiply
# array([[ 1,  0,  1,  4],
#        [ 0,  1,  0, -3],
#        [ 0,  0,  1,  2]])

# %%
#Converts row echelon form to reduced row echelon form.
A = np.array([[2, 4, 6], [3, 8, 5], [-1, 1, 2]], dtype='float')
b = np.array([22, 27, 2])
Ab = np.hstack([A, b.reshape(-1, 1)])

import sympy as sm
np.linalg.solve(A, b)
# Out:
# array([3., 1., 2.])

# %% [markdown]
# ### Task 3
#
# Modify the code from task 2 and use it to solve the following system of linear equations
#
# \begin{equation}
# x_1 - x_2 = 3 \\
# x_1 - x_3 = -2 \\
# -6x_1 + 2x_2 + 3x_3 = 0 \\
# \end{equation}
#
# given that it has unique solution.<br>
# Hint: You will need to make an improvement to the section of the code that converts row echelon form to reduced row echelon form.

# %% [markdown]
# ### Task 4
#
# Given a system of 10 linear equations (below) that has a unique solution, compare the time taken to solve the system of linear equations using your code from task 3 with numpy.linalg.solve.
#
#
# \begin{align*}
# 3x_{1} + 5x_{2} + 4x_{3} + 3x_{4} - 8x_{5} - 8x_{6} - 6x_{7} - 6x_{8} - 6x_{9} - 7x_{10} &= -148 \\
# 6x_{1} + 9x_{2} + 6x_{3} - 3x_{4} + 6x_{5} - 8x_{6} - 7x_{7} + 5x_{8} - 6x_{9} - 3x_{10} &= 29 \\
# 8x_{1} + 3x_{2} - 7x_{3} + x_{4} - 4x_{5} + 3x_{6} - 4x_{7} - 2x_{8} - 6x_{9} + 4x_{10} &= 84 \\
# 4x_{1} - 4x_{2} + 5x_{3} + 7x_{4} - 5x_{5} - 8x_{6} + 5x_{7} + 0x_{8} + 8x_{9} + 8x_{10} &= -88 \\
# 9x_{1} + 8x_{2} + 10x_{3} - 6x_{4} - 3x_{5} - 3x_{6} + 5x_{7} - 8x_{8} - 2x_{9} - 7x_{10} &= -208 \\
# -5x_{1} + x_{2} + 8x_{3} - 3x_{4} + 4x_{5} - 4x_{6} - x_{7} + 6x_{8} - 9x_{9} + x_{10} &= -64 \\
# -8x_{1} - 6x_{2} + 6x_{3} + 0x_{4} + 10x_{5} - 8x_{6} + 4x_{7} + 2x_{8} - 4x_{9} - x_{10} &= -75 \\
# x_{1} + 2x_{2} + x_{3} + 8x_{4} - 4x_{5} + 5x_{6} - 10x_{7} + 7x_{8} + 0x_{9} - 2x_{10} &= 124 \\
# 7x_{1} + 4x_{2} - 6x_{3} - 7x_{4} - 7x_{5} - 10x_{6} - 7x_{7} - 8x_{8} + 8x_{9} + 3x_{10} &= -59 \\
# -2x_{1} - 7x_{2} + 0x_{3} - 3x_{4} + 5x_{5} - 8x_{6} - 6x_{7} - 9x_{8} - 5x_{9} - 3x_{10} &= -62 \\
# \end{align*}

# %%
import timeit

# %%
import timeit
#Find the time taken to solve the system of linear equations using Guassian elimination
Gaussian = '''
import numpy as np
A = np.array([[3, 5, 4, 3, -8, -8, -6, -6, -6, -7], [6, 9, 6, -3, 6, -8, -7, 5, -6, -3], [8, 3, -7, 1, -4, 3, -4, -2, -6, 4], [4, -4, 5, 7, -5, -8, 5, 0, 8, 8], [9, 8, 10, -6, -3, -3, 5, -8, -2, -7], [-5, 1, 8, -3, 4, -4, -1, 6, -9, 1], [-8, -6, 6, 0, 10, -8, 4, 2, -4, -1], [1, 2, 1, 8, -4, 5, -10, 7, 0, -2], [7, 4, -6, -7, -10, -10, -7, -8, 8, 3], [-2, -7, 0, -3, 5, -8, -6, -9, -5, -3]], dtype='float')
b = np.array([-148, 29, 84, -88, -208, -64, -75, 124, -59, -62])
Ab = np.hstack([A, b.reshape(-1, 1)])
n = len(b)

# Put your code from Task 3 here

for i in range(n - 1, -1, -1):
    Ab[i] = Ab[i] / Ab[i, i]
    a = Ab[i]

    for j in range(i - 1, -1, -1):
        b = Ab[j]
        m = a[i] / b[i]
        Ab[j] = a - m * b

x = Ab
print(x)
'''

print("Time taken is ", timeit.timeit(stmt = Gaussian, number = 1))
# Out:
# [[ 1.00000000e+00 -0.00000000e+00  3.94005882e-17 -0.00000000e+00
#   -3.12889375e-17 -0.00000000e+00  4.27805837e-16 -1.57565968e-15
#   -0.00000000e+00 -0.00000000e+00  3.00000000e+00]
#  [ 1.40536774e+00  1.00000000e+00 -2.10420074e-17 -0.00000000e+00
#    1.67099549e-17 -0.00000000e+00 -0.00000000e+00 -1.02703777e-16
#   -0.00000000e+00 -0.00000000e+00  6.21610323e+00]
#  [-4.89195610e-01 -4.82770577e-01  1.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00 -5.95411352e-17
#    0.00000000e+00  0.00000000e+00 -1.04331280e+01]
#  [ 2.15950443e-01 -5.31854169e-01  6.54568639e-01  1.00000000e+00
#   -0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -1.55417371e-16
#   -0.00000000e+00 -0.00000000e+00 -1.65240612e+00]
#  [-8.96864954e-01 -1.26549221e+00 -5.33341434e-01  6.40438267e-01
#    1.00000000e+00 -0.00000000e+00 -0.00000000e+00  4.42154585e-16
#   -0.00000000e+00 -0.00000000e+00  1.06069052e+01]
#  [ 4.37111629e-01  3.55016091e-01 -3.09682345e-01  1.17697653e-01
#   -4.58140456e-01  1.00000000e+00  0.00000000e+00 -8.61092732e-17
#    0.00000000e+00  0.00000000e+00  6.84635233e+00]
#  [ 2.21081081e+00  1.76936937e+00 -1.71171171e+00  6.90090090e-01
#   -2.06126126e+00  5.95315315e+00  1.00000000e+00 -4.72050382e-16
#   -0.00000000e+00 -0.00000000e+00  3.67927928e+01]
#  [-1.01045296e-01  3.13588850e-01  2.40418118e-01  6.62020906e-01
#   -5.57491289e-02  9.51219512e-01  2.64808362e-01  1.00000000e+00
#   -0.00000000e+00  0.00000000e+00  9.40069686e+00]
#  [ 1.66666667e+00 -1.00000000e+00 -2.00000000e+00 -3.33333333e+00
#   -1.66666667e+00 -6.00000000e+00 -4.33333333e+00 -5.66666667e+00
#    1.00000000e+00 -0.00000000e+00 -4.03333333e+01]
#  [ 6.66666667e-01  2.33333333e+00 -0.00000000e+00  1.00000000e+00
#   -1.66666667e+00  2.66666667e+00  2.00000000e+00  3.00000000e+00
#    1.66666667e+00  1.00000000e+00  2.06666667e+01]]
# Time taken is  0.0029796000000006373

# %%
#Find the time taken to solve the system of linear equations using numpy.linalg.solve
Auto = '''
import numpy as np
A = np.array([[3, 5, 4, 3, -8, -8, -6, -6, -6, -7], [6, 9, 6, -3, 6, -8, -7, 5, -6, -3], [8, 3, -7, 1, -4, 3, -4, -2, -6, 4], [4, -4, 5, 7, -5, -8, 5, 0, 8, 8], [9, 8, 10, -6, -3, -3, 5, -8, -2, -7], [-5, 1, 8, -3, 4, -4, -1, 6, -9, 1], [-8, -6, 6, 0, 10, -8, 4, 2, -4, -1], [1, 2, 1, 8, -4, 5, -10, 7, 0, -2], [7, 4, -6, -7, -10, -10, -7, -8, 8, 3], [-2, -7, 0, -3, 5, -8, -6, -9, -5, -3]], dtype='float')
b = np.array([-148, 29, 84, -88, -208, -64, -75, 124, -59, -62])
Ab = np.hstack([A, b.reshape(-1, 1)])
n = len(b)
print(np.linalg.solve(A,b))
'''

print(timeit.timeit(stmt = Auto, number = 10000))
# Out:
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# ...
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# [ 3.  2. -8.  4.  9.  6. -7.  5.  3.  3.]
# 4.1900028

# %% [markdown]
# You will notice that numpy.linalg.solve takes a shorter time to solve the system of linear equations as it uses the LAPACK routine. However, numpy.linalg.solve can only solve a system of linear equations with a unique solution.

# %% [markdown]
# ### Task 5
# If we do not know the number of solutions our system of linear equations has, we can use sympy.linsolve.
#
# For example, we can use sympy.linsolve to solve the following system of linear equations which has many solutions:
# \begin{eqnarray}
# x_1 + x_2 - 5x_3 = 3 \\
# x_1 - 2x_3 = 1 \\
# 2x_1 - x_2 - x_3 = 0
# \end{eqnarray}

# %%
import sympy as sp

# %%
sp.init_printing()

# %%
x1, x2, x3 = sp.symbols('x1 x2 x3')

# %%
A5 = sp.Matrix([[1,1,-5], [1, 0, -2], [2,-1,-1]])

# %%
b5 = sp.Matrix([[3], [1], [0]])

# %%
sp.linsolve((A5, b5), x1, x2, x3)
# Out:
# C:\Users\justi\anaconda3\envs\tensor2\lib\site-packages\IPython\lib\latextools.py:126: MatplotlibDeprecationWarning:
# The to_png function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use mathtext.math_to_image instead.
#   mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
# C:\Users\justi\anaconda3\envs\tensor2\lib\site-packages\IPython\lib\latextools.py:126: MatplotlibDeprecationWarning:
# The to_rgba function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use mathtext.math_to_image instead.
#   mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
# C:\Users\justi\anaconda3\envs\tensor2\lib\site-packages\IPython\lib\latextools.py:126: MatplotlibDeprecationWarning:
# The to_mask function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use mathtext.math_to_image instead.
#   mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
# C:\Users\justi\anaconda3\envs\tensor2\lib\site-packages\IPython\lib\latextools.py:126: MatplotlibDeprecationWarning:
# The MathtextBackendBitmap class was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use mathtext.math_to_image instead.
#   mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
# {(2⋅x₃ + 1, 3⋅x₃ + 2, x₃)}

# %%
arr = np.array([[1, -1], [2, -2]])
np.linalg.det(arr)
# Out:
# 0.0

# %%
arr = np.array([[-1, -4, 0], [3, 12, 0], [2, 8, 0]])
np.linalg.det(arr)
# Out:
# 0.0
